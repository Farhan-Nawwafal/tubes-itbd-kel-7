# %% [markdown]
# # Tugas Besar Infrastruktur dan Teknologi Big Data

# %% [markdown]
# **Link Data: https://www.kaggle.com/datasets/elemento/nyc-yellow-taxi-trip-data?resource=download**

# %% [markdown]
# ## Menyiapkan Libraries yang Dibutuhkan

# %%
import pandas as pd

# %% [markdown]
# ## Gathering Data

# %%
df = pd.read_csv('./dataset/yellow_tripdata_2015-01.csv')
df.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         2  2015-01-15 19:05:39   2015-01-15 19:23:42                1
# 1         1  2015-01-10 20:33:38   2015-01-10 20:53:28                1
# 2         1  2015-01-10 20:33:38   2015-01-10 20:43:41                1
# 3         1  2015-01-10 20:33:39   2015-01-10 20:35:31                1
# 4         1  2015-01-10 20:33:39   2015-01-10 20:52:58                1
#
#    trip_distance  pickup_longitude  pickup_latitude  RateCodeID  \
# 0           1.59        -73.993896        40.750111           1
# 1           3.30        -74.001648        40.724243           1
# 2           1.80        -73.963341        40.802788           1
# 3           0.50        -74.009087        40.713818           1
# 4           3.00        -73.971176        40.762428           1
#
#   store_and_fwd_flag  dropoff_longitude  dropoff_latitude  payment_type  \
# ...

# %% [markdown]
# ## Exploratory Data Analysis

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12748986 entries, 0 to 12748985
# Data columns (total 19 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   VendorID               int64
#  1   tpep_pickup_datetime   object
#  2   tpep_dropoff_datetime  object
#  3   passenger_count        int64
#  4   trip_distance          float64
#  5   pickup_longitude       float64
#  6   pickup_latitude        float64
#  7   RateCodeID             int64
#  8   store_and_fwd_flag     object
#  9   dropoff_longitude      float64
#  10  dropoff_latitude       float64
#  11  payment_type           int64
#  12  fare_amount            float64
#  13  extra                  float64
#  14  mta_tax                float64
#  15  tip_amount             float64
#  16  tolls_amount           float64
#  17  improvement_surcharge  float64
#  18  total_amount           float64
# dtypes: float64(12), int64(4), object(3)
# memory usage: 1.8+ GB

# %% [markdown]
# Insights:
# - Untuk fitur `tpep_pickup_datetime` dan `tpep_dropoff_datetime` tipe datanya adalah `object`. Sedangkan tipe data ini seharusnya bertipe `datetime`.
# - Hal ini akan ditangani pada tahap `preprocessing`
# - Dikarenakan jumlah datanya mencapai `127 ribu data`, maka kami hanya akan mengambil sampel data sebanyak `10 ribu data`

# %%
# Mengambil 5000 data pertama
df_slicing = df.head(5000)

# %%
# Cek Struktur Fitur
df_slicing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   VendorID               5000 non-null   int64
#  1   tpep_pickup_datetime   5000 non-null   object
#  2   tpep_dropoff_datetime  5000 non-null   object
#  3   passenger_count        5000 non-null   int64
#  4   trip_distance          5000 non-null   float64
#  5   pickup_longitude       5000 non-null   float64
#  6   pickup_latitude        5000 non-null   float64
#  7   RateCodeID             5000 non-null   int64
#  8   store_and_fwd_flag     5000 non-null   object
#  9   dropoff_longitude      5000 non-null   float64
#  10  dropoff_latitude       5000 non-null   float64
#  11  payment_type           5000 non-null   int64
#  12  fare_amount            5000 non-null   float64
#  13  extra                  5000 non-null   float64
# ...

# %% [markdown]
# Insight:
# - Jumlah baris data sudah sebanyak `10 ribu baris`, namun tipe data untuk fitur `tpep_pickup_datetime` dan `tpep_dropoff_datetime` masih belum tepat

# %%
# Cek missing value
df_slicing.isna().sum()
# Out:
# VendorID                 0
# tpep_pickup_datetime     0
# tpep_dropoff_datetime    0
# passenger_count          0
# trip_distance            0
# pickup_longitude         0
# pickup_latitude          0
# RateCodeID               0
# store_and_fwd_flag       0
# dropoff_longitude        0
# dropoff_latitude         0
# payment_type             0
# fare_amount              0
# extra                    0
# mta_tax                  0
# tip_amount               0
# tolls_amount             0
# improvement_surcharge    0
# total_amount             0
# dtype: int64

# %%
# Cek dupikasi data
print(f' Jumlah data duplikat: {df_slicing.duplicated().sum()}')
# Out:
#  Jumlah data duplikat: 0

# %%
df_slicing.to_csv('./dataset/yellow_tripdata_2015-01_fix.csv')

# %% [markdown]
# ### Univariate Analysis - Melihat Distribusi Data untuk Fitur-Fitur Numerik

# %%
# Set Tema Visualisasi
sns.set_theme(style='whitegrid')

# %%
# Seleksi Fitur untuk Numerik
num_cols = [
            'passenger_count',
            'trip_distance',
            'pickup_longitude',
            'pickup_latitude',
            'RateCodeID',
            'dropoff_latitude',
            'payment_type',
            'fare_amount',
            'extra',
            'mta_tax',
            'tip_amount',
            'tolls_amount',
            'improvement_surcharge',
            'total_amount' 
            ]
