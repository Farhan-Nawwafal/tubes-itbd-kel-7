# %% [markdown]
# # Tugas Besar Infrastruktur dan Teknologi Big Data

# %% [markdown]
# **Link Data: https://www.kaggle.com/datasets/elemento/nyc-yellow-taxi-trip-data?resource=download**

# %% [markdown]
# ## Menyiapkan Libraries yang Dibutuhkan

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Gathering Data

# %%
df = pd.read_csv('./dataset/yellow_tripdata_2015-01_fix.csv').iloc[:, 2:]
df.head()
# Out:
#   tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  trip_distance  \
# 0  2015-01-15 19:05:39   2015-01-15 19:23:42                1           1.59
# 1  2015-01-10 20:33:38   2015-01-10 20:53:28                1           3.30
# 2  2015-01-10 20:33:38   2015-01-10 20:43:41                1           1.80
# 3  2015-01-10 20:33:39   2015-01-10 20:35:31                1           0.50
# 4  2015-01-10 20:33:39   2015-01-10 20:52:58                1           3.00
#
#    pickup_longitude  pickup_latitude  RateCodeID store_and_fwd_flag  \
# 0        -73.993896        40.750111           1                  N
# 1        -74.001648        40.724243           1                  N
# 2        -73.963341        40.802788           1                  N
# 3        -74.009087        40.713818           1                  N
# 4        -73.971176        40.762428           1                  N
#
#    dropoff_longitude  dropoff_latitude  payment_type  fare_amount  extra  \
# ...

# %% [markdown]
# ## Exploratory Data Analysis

# %%
# Melihat Informasi Fitur
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   tpep_pickup_datetime   5000 non-null   object
#  1   tpep_dropoff_datetime  5000 non-null   object
#  2   passenger_count        5000 non-null   int64
#  3   trip_distance          5000 non-null   float64
#  4   pickup_longitude       5000 non-null   float64
#  5   pickup_latitude        5000 non-null   float64
#  6   RateCodeID             5000 non-null   int64
#  7   store_and_fwd_flag     5000 non-null   object
#  8   dropoff_longitude      5000 non-null   float64
#  9   dropoff_latitude       5000 non-null   float64
#  10  payment_type           5000 non-null   int64
#  11  fare_amount            5000 non-null   float64
#  12  extra                  5000 non-null   float64
#  13  mta_tax                5000 non-null   float64
# ...

# %% [markdown]
# Insights:
# - Data berisi `5000 baris data`
# - Fitur `tpep_pickup_datetime` dan `tpep_dropoff_datetime` memiliki tipe data yang kurang tepat. Seharusnya tipe datanya `datetime`bukan `object`
# - Karena jumlah baris pada tiap fitur sama, maka data ini `tidak memiliki missing value`

# %%
# Memastikan Missing Value
df.isna().sum()
# Out:
# tpep_pickup_datetime     0
# tpep_dropoff_datetime    0
# passenger_count          0
# trip_distance            0
# pickup_longitude         0
# pickup_latitude          0
# RateCodeID               0
# store_and_fwd_flag       0
# dropoff_longitude        0
# dropoff_latitude         0
# payment_type             0
# fare_amount              0
# extra                    0
# mta_tax                  0
# tip_amount               0
# tolls_amount             0
# improvement_surcharge    0
# total_amount             0
# dtype: int64

# %% [markdown]
# Insights:
# - Sesuai insights sebelumnya, data ini `tidak memiliki missing value`

# %%
# Cek Duplikasi Data
print(f'Jumlah duplikasi data: {df.duplicated().sum()} baris data')
# Out:
# Jumlah duplikasi data: 0 baris data

# %% [markdown]
# Insights:
# - Data ini juga tidak memiliki `duplikasi data`, sehingga data ini sudah bersih
